# %% [markdown]
# # Working with JSON

# %% [markdown]
# **JSON (JavaScript Object Notation)**
#
# * Overview :
#
#     *What is JSON?*
#
#     - Text-based format for storing and exchanging structured data
#
#     - Commonly used in APIs and web services
#
#     - Easy to read by humans and machines
#
#
# * *Why JSON Matters?*
#
#     - Widely used in real-world data engineering and analytics workflows
#
#     - Many web APIs return JSON
#
#     - JSON supports nested structures that go beyond tabular data

# %%
import pandas as pd

df = pd.json_normalize(data)

'''
=> json_normalize flattens nested JSON into tabular format
=> Useful when rows contain nested dictionaries/lists
'''

# %% [markdown]
# # Working with SQL

# %% [markdown]
# - SQL (Structured Query Language) is used to manage relational databases
#
# - Stores data in tables with rows and columns
#
# - Integration with Python enables powerful data workflows

# %% [markdown]
# # Comparision

# %% [markdown]
# | Feature                 | JSON                       | SQL                        |               |
# | ----------------------- | -------------------------- | -------------------------- | ------------- |
# | Structure               | Hierarchical / nested      | Tabular                    |               |
# | Best for                | API responses, config data | Large relational data      |               |
# | Flexibility             | High (nested)              | Strict schema              |               |
# | Typical Python handling | `json`, `json_normalize`   | `read_sql_query`, `to_sql` |
